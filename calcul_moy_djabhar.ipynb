# %%
som_1 = 0
coef_1 = 0
moy_1 = 0

for i in range(101, 104):
   note = float(input("Donnez-moi la note de la ressource R{}".format(i)))
   coef = int(input("Donnez-moi le coefficient de la ressource R{}".format(i)))
   som_1 += note * coef
   coef_1 += coef

for i in range(11, 13):
   note = float(input("Donnez-moi la note de la SAE SAE{}".format(i)))
   coef = int(input("Donnez-moi le coefficient de la SAE SAE{}".format(i)))
   som_1 += note * coef
   coef_1 += coef

moy_1 = som_1 / coef_1
print("Votre moyenne est du U1 est ", moy_1)
# Out:
# Donnez-moi la note de la ressource R101 2
# Donnez-moi le coefficient de la ressource R101 2
# Donnez-moi la note de la ressource R102 2
# Donnez-moi le coefficient de la ressource R102 2
# Donnez-moi la note de la ressource R103 2
# Donnez-moi le coefficient de la ressource R103 2
# Donnez-moi la note de la SAE SAE11 2
# Donnez-moi le coefficient de la SAE SAE11 2
# Donnez-moi la note de la SAE SAE12 2
# Donnez-moi le coefficient de la SAE SAE12 2
# Votre moyenne est de 2.0
